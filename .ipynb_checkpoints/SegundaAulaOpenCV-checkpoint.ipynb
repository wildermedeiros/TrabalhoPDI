# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('ni/ge.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgbImg)

# %%
rgbImg.shape
# Out:
# (1280, 960, 3)

# %%
plt.imshow(rgbImg)

# %%
r, g, b = cv2.split(rgbImg)

# %%
plt.imshow(r)

# %%
plt.imshow(g)

# %%
plt.imshow(b)
